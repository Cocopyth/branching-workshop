# %%
from pathlib import Path
import numpy as np
from read import  read_graph_file
from matplotlib import cm, pyplot as plt
import networkx as nx

# %%
path_test = r""
path = Path(path_test,"20241201_0152.geojson")
graph = read_graph_file(path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 path_test = r""
#       2 path = Path(path_test,"20241201_0152.geojson")
# ----> 3 graph = read_graph_file(path)
#
# File ~\Documents\PostDoc1\BranchingWorkshop\read.py:21, in read_graph_file(filename)
#      10 """
#      11 Read a GeoJSON file into a NetworkX graph, preserving node and edge attributes.
#      12
#    (...)     17 - G: NetworkX graph with spatial data.
#      18 """
#      19 G = nx.Graph()
# ---> 21 with open(filename, "r") as f:
#      22     data = geojson.load(f)
#      24 # Process each feature in the GeoJSON
#
# FileNotFoundError: [Errno 2] No such file or directory: '20241201_0152.geojson'

# %%
fig, ax = plt.subplots()
edgelist = list(graph.edges())
rotated_pos = {node: (attrs["position"].y, -attrs["position"].x) for node, attrs in graph.nodes(data=True)}

nx.draw_networkx(
    graph,
    pos=rotated_pos,
    with_labels=False,
    nodelist=[],  # Set the nodes corresponding to the edges
    edgelist=edgelist,
    width=1,
    ax=ax
)
plt.gca().set_aspect('equal')
